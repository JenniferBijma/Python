# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Importing Data

# %%
# Create Path
path = r'C:\Users\jenni\OneDrive\Documenten\Data Analyst Program\Data Analytics Immersion\Achievement 4\02-2024 Instacart Basket Analysis'

# %%
df_ord_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df = df_ord_prods_merged[:1000000]

# %% [markdown]
# # Exercise

# %%
# Defining Price Labels

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\jenni\AppData\Local\Temp\ipykernel_10892\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.value_counts()
# Out:
# Unnamed: 0.1_x  Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  orders_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  reordered  Unnamed: 0.1_y  Unnamed: 0_y  product_name            aisle_id  department_id  prices  _merge  price_range
# 0               0             2539329   1        1             2                   8                   11.0                    196         1                  0          192             195           Soda                    77        7              9.0     both    Mid-range product    1
# 2249712         2249712       2619719   135483   16            2                   13                  30.0                    30450       2                  1          30435           30452         Creamy Almond Butter    88        13             3.2     both    Low-range product    1
# ...

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## Making If-Statement for Limited Dataframe

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\jenni\AppData\Local\Temp\ipykernel_10892\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Checking Count for the Dataframe
df.value_counts()
# Out:
# Unnamed: 0.1_x  Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  orders_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  reordered  Unnamed: 0.1_y  Unnamed: 0_y  product_name            aisle_id  department_id  prices  _merge  price_range        price_range_loc
# 0               0             2539329   1        1             2                   8                   11.0                    196         1                  0          192             195           Soda                    77        7              9.0     both    Mid-range product  Mid-range product    1
# 2249712         2249712       2619719   135483   16            2                   13                  30.0                    30450       2                  1          30435           30452         Creamy Almond Butter    88        13             3.2     both    Low-range product  Low-range product    1
# ...

# %% [markdown]
# ## Making If-Statement for Entire Dataframe

# %%
df_ord_prods_merged.loc[(df_ord_prods_merged['prices'] <= 15) & (df_ord_prods_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ord_prods_merged.loc[df_ord_prods_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ord_prods_merged.loc[df_ord_prods_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# Checking counts for the New Price Range Column
df_ord_prods_merged['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
# Checking counts for Orders per Day
df_ord_prods_merged['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# Creating labels for busiest, least busy and regularly busy days
result = []

for value in df_ord_prods_merged["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
# Naming the new Busiest Day Column
df_ord_prods_merged['busiest_day'] = result

# %%
# Checking Counts of new Column
df_ord_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # Task

# %%
# Creating labels for 2 busiest, 2 least busy and regularly busy days
result = []

for value in df_ord_prods_merged["orders_day_of_week"]:
  if value == 0 or value == 1:
    result.append("Busiest day")
  elif value == 4 or value == 3:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Least busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
# ...

# %%
# Naming the new Busiest Days Column
df_ord_prods_merged['busiest_days'] = result

# %%
# Checking Counts of new Busiest Days Column
df_ord_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest day       11864412
# Least busy         7624336
# Name: count, dtype: int64

# %% [markdown]
# Now, in contrast to the busiest days column, the amount of busiest days are almost as high as those of regular days

# %%
# Checking Counts of Hour of Day
df_ord_prods_merged['orders_hour_of_day'].value_counts(dropna = False)
# Out:
# orders_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
  # Creating Labels for Busiest Hours
    
result = []
    
for value in df_ord_prods_merged['orders_hour_of_day']:
    if value == 10 or value == 11 or value == 14 or value == 15 or value == 13 or value == 12 or value == 16:
        result.append('Most orders')
    elif value == 9 or value == 17 or value == 8 or value == 18 or value == 19 or value == 20:
        result.append('Average orders')
    else:
        result.append('Fewest orders')

# %%
result
# Out:
# ['Average orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Fewest orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Fewest orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# Assign Busiest Period of Day Column Column to Created Labels
df_ord_prods_merged['busiest_period_of_day'] = result

# %%
# Checking Counts of Busiest Period of Day Column
df_ord_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# busiest_period_of_day
# Most orders       18663868
# Average orders    10130938
# Fewest orders      3610053
# Name: count, dtype: int64

# %%
# Export Data as Pickle
df_ord_prods_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_new_var.pkl'))
